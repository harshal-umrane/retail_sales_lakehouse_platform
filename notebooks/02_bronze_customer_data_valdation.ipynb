# %%
customer_df = spark.read \
    .format("delta") \
    .load("abfss://bronze@saretailsales.dfs.core.windows.net/customers/")

# %%
customer_df.printSchema()
# Out:
# root
#  |-- customer_id: long (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- last_name: string (nullable = true)
#  |-- dob: date (nullable = true)
#  |-- email: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- pincode: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- phone: string (nullable = true)
#  |-- registration_date: string (nullable = true)

# %%
duplicate_customers = customer_df \
    .groupBy('customer_id') \
    .count().filter('count(1) > 1')

duplicate_email = customer_df \
    .groupBy('email') \
    .count().filter('count(1) > 1')

display(duplicate_email)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>email</th><th>count</th></tr></thead><tbody><tr><td>hsinghal@example.com</td><td>2</td></tr></tbody></table></div>

# %%
null_customerid = customer_df.filter("customer_id is null")

null_emails = customer_df.filter("email is null")

gender_validation = customer_df.filter("gender not in ('Male', 'Female')")

display(gender_validation)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>first_name</th><th>last_name</th><th>dob</th><th>email</th><th>gender</th><th>address</th><th>city</th><th>state</th><th>pincode</th><th>country</th><th>phone</th><th>registration_date</th></tr></thead><tbody></tbody></table></div>

# %%
future_date_registeration = customer_df.filter("registration_date > current_date")

display(future_date_registeration)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>first_name</th><th>last_name</th><th>dob</th><th>email</th><th>gender</th><th>address</th><th>city</th><th>state</th><th>pincode</th><th>country</th><th>phone</th><th>registration_date</th></tr></thead><tbody></tbody></table></div>

# %%
phoneno_length = customer_df.filter("length(phone) != 10")

display(phoneno_length)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>first_name</th><th>last_name</th><th>dob</th><th>email</th><th>gender</th><th>address</th><th>city</th><th>state</th><th>pincode</th><th>country</th><th>phone</th><th>registration_date</th></tr></thead><tbody><tr><td>1</td><td>Bakhshi</td><td>Sabharwal</td><td>2021-10-22</td><td>pranittara@example.net</td><td>Male</td><td>530, Chada Ganj, Kanpur 933434</td><td>Sirsa</td><td>Uttarakhand</td><td>337215</td><td>Tuvalu</td><td>+914024314431</td><td>2025-01-14</td></tr><tr><td>2</td><td>Chameli</td><td>Madan</td><td>2003-02-26</td><td>pantveer@example.com</td><td>Male</td><td>94/36
# Bala Chowk, Sambalpur-694107</td><td>Tenali</td><td>West Bengal</td><td>304060</td><td>Oman</td><td>+916508265898</td><td>2025-07-22</td></tr><tr><td>3</td><td>Rishi</td><td>Guha</td><td>1912-04-25</td><td>pratyush12@example.com</td><td>Female</td><td>H.No. 702
# Dutta Zila
# Tirupati-531860</td><td>Bhalswa Jahangir Pur</td><td>Jharkhand</td><td>010627</td><td>Tuvalu</td><td>07260614196</td><td>2025-04-03</td></tr><tr><td>4</td><td>Jagat</td><td>Patel</td><td>1993-10-28</td><td>bahljacob@example.net</td><td>Female</td><td>H.No. 556, Sarkar Zila
# Bellary-792120</td><td>Sirsa</td><td>Manipur</td><td>157943</td><td>Serbia</td><td>+911571282272</td><td>2025-06-25</td></tr><tr><td>5</td><td>Ranbir</td><td>Lalla</td><td>1997-10-09</td><td>gnanda@example.com</td><td>Male</td><td>H.No. 509, Prabhakar Circle
# Guna 268801</td><td>Jorhat</td><td>Punjab</td><td>274935</td><td>Zimbabwe</td><td>+914294586938</td><td>2024-11-23</td></tr><tr><td>6</td><td>Lavanya</td><td>Sheth</td><td>1960-11-29</td><td>gperi@example.org</td><td>Male</td><td>085
